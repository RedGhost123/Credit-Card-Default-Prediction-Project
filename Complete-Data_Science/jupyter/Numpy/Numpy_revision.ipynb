# %%
import numpy as np  # 2005 by travis Oliphant

# %%
np.__version__
# Out:
# '1.26.4'

# %%
print(np.__doc__)
# Out:
# NumPy
# =====
#
# Provides
#   1. An array object of arbitrary homogeneous items
#   2. Fast mathematical operations over arrays
#   3. Linear Algebra, Fourier Transforms, Random Number Generation
#
# How to use the documentation
# ----------------------------
# Documentation is available in two forms: docstrings provided
# with the code, and a loose standing reference guide, available from
# `the NumPy homepage <https://numpy.org>`_.
#
# We recommend exploring the docstrings using
# `IPython <https://ipython.org>`_, an advanced Python shell with
# TAB-completion and introspection capabilities.  See below for further
# instructions.
#
# The docstring examples assume that `numpy` has been imported as ``np``::
#
#   >>> import numpy as np
#
# Code snippets are indicated by three greater-than signs::
#
#   >>> x = 42
#   >>> x = x + 1
#
# Use the built-in ``help`` function to view a function's docstring::
#
#   >>> help(np.sort)
#   ... # doctest: +SKIP
#
# ...

# %%
l = [1,2,3,4,5]

# %%
# numpy have a properties that they can convert list into array

# Converting list into array
arr = np.array(l)

# %%
# checking dimension of array
arr.ndim
# Out:
# 1

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
# Adding String value in integer list ..
l1 = [1,2,3,4,5,"vaibhav"]

# %%
arr1 = np.array(l1)

# %%
# Adding single string in list that change whole data type of list ..
arr1
# Out:
# array(['1', '2', '3', '4', '5', 'vaibhav'], dtype='<U11')

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr1.dtype
# Out:
# dtype('<U11')

# %% [markdown]
# 2_D array

# %%
arr2 = np.array([[1,2,3],[4,5,6]])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr2.ndim
# Out:
# 2

# %%
l = [1,2,3,4]

# %%
np.array(l)  # This is one dimension array
# Out:
# array([1, 2, 3, 4])

# %%
mat = np.matrix(l) # Matrix function by default convert in 2-d Array

# %%
# Making 3_D array
arr3d = np.array([[[1,2],[3,4],[6,7]]])

# %%
arr3d
# Out:
# array([[[1, 2],
#         [3, 4],
#         [6, 7]]])

# %%
arr3d.ndim  # Checking dimension of the array
# Out:
# 3

# %%
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
mat
# Out:
# matrix([[1, 2, 3, 4]])

# %%
np.asanyarray(mat) # They not convert matrix into array because this function cannot convert any subclass a
# and matrix is subclass of array
# Out:
# matrix([[1, 2, 3, 4]])

# %%
# you can convert matrix into array using asarray of array
np.array(mat)
# Out:
# array([[1, 2, 3, 4]])

# %%
np.asarray(mat) # converting matrix into array
# Out:
# array([[1, 2, 3, 4]])
