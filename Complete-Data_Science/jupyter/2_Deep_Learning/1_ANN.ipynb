# %%
import tensorflow as tsf

# %%
from tensorflow import keras

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()

# %%
x = iris.data

# %%
y = iris.target

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
y = to_categorical(y,num_classes=3)

# %% [markdown]
# ### Train Test Split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Scalling

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train.shape[1]
# Out:
# 4

# %%
reg1 = keras.regularizers.L2(l2 = 0.5)

# %%
reg2 = keras.regularizers.L2(l2 = 0.1)

# %%
reg3 = keras.regularizers.L2(l2 = 0.5)

# %%
model = Sequential()

# %%
model.add(Dense(10,activation='relu',input_shape = (x_train.shape[1],)))

# %%
model.add(Dense(5,activation='relu'))

# %%
model.add(Dense(3,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 10)             │            50 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 123 (492.00 B)
#  Trainable params: 123 (492.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.3277 - loss: 1.1799 - val_accuracy: 0.2667 - val_loss: 1.2203
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3137 - loss: 1.1712 - val_accuracy: 0.2667 - val_loss: 1.2029
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3033 - loss: 1.1615 - val_accuracy: 0.2667 - val_loss: 1.1855
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3446 - loss: 1.1440 - val_accuracy: 0.2333 - val_loss: 1.1685
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3575 - loss: 1.1162 - val_accuracy: 0.2667 - val_loss: 1.1511
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3471 - loss: 1.1012 - val_accuracy: 0.3000 - val_loss: 1.1342
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3052 - loss: 1.1205 - val_accuracy: 0.3333 - val_loss: 1.1182
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3458 - loss: 1.0851 - val_accuracy: 0.3333 - val_loss: 1.1032
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3850 - loss: 1.0664 - val_accuracy: 0.3667 - val_loss: 1.0878
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4217 - loss: 1.0531 - val_accuracy: 0.5000 - val_loss: 1.0716
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4602 - loss: 1.0763 - val_accuracy: 0.5000 - val_loss: 1.0563
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5081 - loss: 1.0372 - val_accuracy: 0.5667 - val_loss: 1.0413
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5756 - loss: 1.0342 - val_accuracy: 0.6333 - val_loss: 1.0263
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6463 - loss: 1.0029 - val_accuracy: 0.6667 - val_loss: 1.0117
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6181 - loss: 1.0094 - val_accuracy: 0.6667 - val_loss: 0.9970
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6817 - loss: 0.9808 - val_accuracy: 0.7000 - val_loss: 0.9822
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6683 - loss: 0.9734 - val_accuracy: 0.6667 - val_loss: 0.9674
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6329 - loss: 0.9681 - val_accuracy: 0.6333 - val_loss: 0.9532
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6635 - loss: 0.9627 - val_accuracy: 0.6333 - val_loss: 0.9389
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6748 - loss: 0.9619 - val_accuracy: 0.6667 - val_loss: 0.9244
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.