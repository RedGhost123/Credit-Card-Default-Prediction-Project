# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("Titanic_Datasets.csv")   #("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# ### Saving dataset from github to local file

# %%
# df.to_csv("Titanic_Dataset.csv")

# %% [markdown]
# ### Resetting Index of DataSet

# %%
df.reset_index(drop =True, inplace = True)

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 886                     Montvila, Rev. Juozas    male  27.0      0      0
# 887              Graham, Miss. Margaret Edith  female  19.0      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 886      211536  13.00   NaN        S
# 887      112053  30.00   B42        S
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Method - Read Data > Understanding the data > business Understanding > Staticals Check

# %% [markdown]
# ## Reading Numerical Data

# %% [markdown]
# ### 1(i)

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %% [markdown]
# ### Reading description (Count - numbers, mean - average, std - Standerd deviation, min - minimum, 25% - 25 percentile or less than 25, Max - Maximum)

# %% [markdown]
# ### 1(ii)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %% [markdown]
# ### Checking all columns

# %%
df.columns  # or list(df.columns)
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 1(iii). Making Data Frame

# %%
df[['PassengerId','Survived','Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %% [markdown]
# ### 1(iv). Checking object types of data

# %%
df.dtypes == object
# Out:
# Unnamed: 0     False
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# ### 1(v). Getting data of only objects type

# %%
df.dtypes[df.dtypes =='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# ### 2(i). Making DataFrame of objects

# %%
df[df.dtypes[df.dtypes == 'object'].index] # or  -> Simple code   -->>>   df[df.columns[df.dtypes == 'object']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %% [markdown]
# ### 2(ii) Making Dataframe of Float-64

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### 2(iii) Making DataFrame of Int-64

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  SibSp  Parch
# 0             0            1         0       3      1      0
# 1             1            2         1       1      1      0
# 2             2            3         1       3      0      0
# 3             3            4         1       1      1      0
# 4             4            5         0       3      0      0
# ..          ...          ...       ...     ...    ...    ...
# 886         886          887         0       2      0      0
# 887         887          888         1       1      0      0
# 888         888          889         0       3      1      2
# 889         889          890         1       1      0      0
# 890         890          891         0       3      0      0
#
# [891 rows x 6 columns]

# %% [markdown]
# ### 2(iv) Making DataFrame of all Values except object

# %%
df[df.dtypes[df.dtypes != 'object'].index]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0             0            1         0       3  22.0      1      0   7.2500
# 1             1            2         1       1  38.0      1      0  71.2833
# 2             2            3         1       3  26.0      0      0   7.9250
# 3             3            4         1       1  35.0      1      0  53.1000
# 4             4            5         0       3  35.0      0      0   8.0500
# ..          ...          ...       ...     ...   ...    ...    ...      ...
# 886         886          887         0       2  27.0      0      0  13.0000
# 887         887          888         1       1  19.0      0      0  30.0000
# 888         888          889         0       3   NaN      1      2  23.4500
# 889         889          890         1       1  26.0      0      0  30.0000
# 890         890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %% [markdown]
# ### 2(v). Making DataFrame of all values

# %%
dataframe = pd.DataFrame(df)
dataframe
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### Geting String Value

# %%
df[df.columns[df.dtypes == 'object']].describe()  # different method -->>>  df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# ### 3(i). Getting String Value With different Method

# %%
df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# ### 3(ii). Getting All Values

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0  PassengerId    Survived      Pclass  \
# count   891.000000   891.000000  891.000000  891.000000
# unique         NaN          NaN         NaN         NaN
# top            NaN          NaN         NaN         NaN
# freq           NaN          NaN         NaN         NaN
# mean    445.000000   446.000000    0.383838    2.308642
# std     257.353842   257.353842    0.486592    0.836071
# min       0.000000     1.000000    0.000000    1.000000
# 25%     222.500000   223.500000    0.000000    2.000000
# 50%     445.000000   446.000000    0.000000    3.000000
# 75%     667.500000   668.500000    1.000000    3.000000
# max     890.000000   891.000000    1.000000    3.000000
#
#                            Name   Sex         Age       SibSp       Parch  \
# count                       891   891  714.000000  891.000000  891.000000
# unique                      891     2         NaN         NaN         NaN
# ...

# %% [markdown]
# ### 3(iii) (df.astype) is only used for object

# %%
df.astype('object').describe()
# Out:
#         Unnamed: 0  PassengerId  Survived  Pclass                     Name  \
# count          891          891       891     891                      891
# unique         891          891         2       3                      891
# top              0            1         0       3  Braund, Mr. Owen Harris
# freq             1            1       549     491                        1
#
#          Sex    Age  SibSp  Parch  Ticket    Fare    Cabin Embarked
# count    891  714.0    891    891     891  891.00      204      889
# unique     2   88.0      7      7     681  248.00      147        3
# top     male   24.0      0      0  347082    8.05  B96 B98        S
# freq     577   30.0    608    678       7   43.00        4      644

# %% [markdown]
# ## 3(iv).  Deleting Columns in DataSets

# %%
# df.drop(df.columns[[1]],axis=1,inplace=True)        # df.drop('Unnamed: 0.6',axis=1,inplace=True)

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### Saving Dataset in Local file

# %%
# df.to_csv("Titanic_Dataset.csv")

# %% [markdown]
# ### Checking Category of Passenger Class

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %% [markdown]
# ### Checking Category of Cabin

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %% [markdown]
# ### Checking All Cabin Name

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %% [markdown]
# ### Checking number of unique Cabin

# %%
df['Cabin'].nunique()
# Out:
# 147

# %% [markdown]
# ### Checking how many people in one Cabin

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0  PassengerId    Survived      Pclass         Age  \
# count  891.000000   891.000000  891.000000  891.000000  714.000000
# mean   445.000000   446.000000    0.383838    2.308642   29.699118
# std    257.353842   257.353842    0.486592    0.836071   14.526497
# min      0.000000     1.000000    0.000000    1.000000    0.420000
# 25%    222.500000   223.500000    0.000000    2.000000   20.125000
# 50%    445.000000   446.000000    0.000000    3.000000   28.000000
# 75%    667.500000   668.500000    1.000000    3.000000   38.000000
# max    890.000000   891.000000    1.000000    3.000000   80.000000
#
#             SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000
# mean     0.523008    0.381594   32.204208
# std      1.102743    0.806057   49.693429
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %% [markdown]
# ### Checking How many passenger are less than 5 years

# %%
df[df['Age'] < 5]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 7             7            8         0       3
# 10           10           11         1       3
# 16           16           17         0       3
# 43           43           44         1       2
# 63           63           64         0       3
# 78           78           79         1       2
# 119         119          120         0       3
# 164         164          165         0       3
# 171         171          172         0       3
# 172         172          173         1       3
# 183         183          184         1       2
# 184         184          185         1       3
# 193         193          194         1       2
# 205         205          206         0       3
# 261         261          262         1       3
# 297         297          298         0       1
# 305         305          306         1       1
# 340         340          341         1       2
# 348         348          349         1       3
# ...

# %% [markdown]
# ### Checking Numbers of Child

# %%
len(df[df['Age'] < 5])
# Out:
# 40

# %% [markdown]
# ### Checking all data of child

# %%
df[df['Age']<5].value_counts()
# Out:
# Unnamed: 0  PassengerId  Survived  Pclass  Name                             Sex     Age   SibSp  Parch  Ticket   Fare      Cabin    Embarked
# 10          11           1         3       Sandstrom, Miss. Marguerite Rut  female  4.00  1      1      PP 9549  16.7000   G6       S           1
# 183         184          1         2       Becker, Master. Richard F        male    1.00  2      1      230136   39.0000   F4       S           1
# 193         194          1         2       Navratil, Master. Michel M       male    3.00  1      1      230080   26.0000   F2       S           1
# 205         206          0         3       Strom, Miss. Telma Matilda       female  2.00  0      1      347054   10.4625   G6       S           1
# 297         298          0         1       Allison, Miss. Helen Loraine     female  2.00  1      2      113781   151.5500  C22 C26  S           1
# ...

# %% [markdown]
# ### Checking number of passenger greater than 18 years

# %%
df[df['Age'] > 18]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 885         885          886         0       3
# 886         886          887         0       2
# 887         887          888         1       1
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### Checking Passenger lesser than 18

# %%
len(df[df['Age'] < 18])
# Out:
# 113

# %% [markdown]
# ### Price of ticket for average passenger

# %%
len(df[df['Fare'] <32])
# Out:
# 680

# %% [markdown]
# ### List of passenger who pay less than 32 fare value

# %%
list(df[df['Fare']  > 32].Name)
# Out:
# ['Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'McCarthy, Mr. Timothy J',
#  'Sloper, Mr. William Thompson',
#  'Fortune, Mr. Charles Alexander',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Meyer, Mr. Edgar Joseph',
#  'Holverson, Mr. Alexander Oskar',
#  'Laroche, Miss. Simonne Marie Anne Andree',
#  'Panula, Master. Juha Niilo',
#  'Harper, Mrs. Henry Sleeper (Myna Haxtun)',
#  'Ostby, Mr. Engelhart Cornelius',
#  'Woolner, Mr. Hugh',
#  'Goodwin, Master. William Frederick',
#  'Icard, Miss. Amelie',
#  'Harris, Mr. Henry Birkhardt',
#  'Goodwin, Miss. Lillian Amy',
#  'Hood, Mr. Ambrose Jr',
#  'Bing, Mr. Lee',
#  'Carrau, Mr. Francisco M',
#  'Ford, Mr. William Neal',
#  'Fortune, Miss. Mabel Helen',
#  'Chaffee, Mr. Herbert Fuller',
#  'Goldschmidt, Mr. George B',
#  'Greenfield, Mr. William Bertram',
#  'White, Mr. Richard Frasar',
#  'Porter, Mr. Walter Chamberlain',
#  'Baxter, Mr. Quigg Edmond',
# ...

# %% [markdown]
# ### Checking, how many passenger are male and female

# %% [markdown]
# ### 1(i)

# %%
# For Female

#1 - df[df['Sex'] == 'female']
len(df[df['Sex'] == 'female'])
# Out:
# 314

# %% [markdown]
# ### 1(ii)

# %%
# For Male
len(df[df['Sex']== 'male'])
# Out:
# 577

# %% [markdown]
# ### 1(iii). Checking Male and Female

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Survived'].value_counts() # 0 - Not Survived, 1 - Survided
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ### Checking percentage of people survived or not

# %%
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %% [markdown]
# ### Checking How many female paying more than avg fare

# %%
len(df[(df['Sex'] == 'female') & (df['Fare'] > df['Fare'].mean())])
# Out:
# 104

# %% [markdown]
# ### Checking Male passenger paying greater than avg fare

# %%
len(df[(df['Sex'] == 'male') & (df['Fare'] > df['Fare'].mean())])
# Out:
# 107
