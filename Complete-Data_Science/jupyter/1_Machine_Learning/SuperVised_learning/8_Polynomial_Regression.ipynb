# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(1)

# %%
x = 2*np.random.rand(100,1)

# %%
y = 4+3*x+1.5*x**2+np.random.rand(100,1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
x_train
# Out:
# array([[9.01747873e-01],
#        [3.63225703e-01],
#        [1.20943220e+00],
#        [1.36418697e-01],
#        [1.14497703e+00],
#        [6.30489606e-01],
#        [1.35813767e+00],
#        [1.17366668e+00],
#        [1.61898138e+00],
#        [9.80507045e-01],
#        [1.05542929e+00],
#        [1.94756708e+00],
#        [8.53402019e-01],
#        [1.01132433e+00],
#        [5.40416524e-01],
#        [1.78577742e+00],
#        [1.22406235e+00],
#        [1.54176782e+00],
#        [1.16402836e+00],
#        [1.96563423e+00],
#        [3.68020403e-01],
#        [1.65769162e+00],
#        [6.89473305e-01],
#        [7.80015428e-01],
#        [5.71152563e-01],
#        [1.83720356e+00],
#        [6.64127149e-01],
#        [1.60432217e+00],
#        [1.28313242e+00],
#        [1.94760416e+00],
#        [9.19760532e-01],
#        [1.34157758e+00],
#        [8.02959167e-01],
#        [1.15571443e+00],
#        [8.40387360e-01],
#        [1.46628505e+00],
#        [1.85236285e+00],
#        [1.50004353e+00],
#        [1.90035224e+00],
#        [1.03802325e+00],
#        [1.25615240e+00],
#        [2.61993690e-01],
#        [1.71662767e+00],
#        [1.39611450e+00],
#        [1.09909584e+00],
#        [7.55848359e-01],
#        [2.52659039e-01],
#        [7.64205504e-01],
#        [1.70979589e+00],
#        [2.70158316e-01],
#        [1.81078464e+00],
#        [1.68946889e+00],
#        [1.92652506e+00],
#        [1.65423094e+00],
#        [3.52392511e-01],
#        [8.04049783e-04],
#        [1.88021496e+00],
#        [1.20862097e+00],
#        [6.34767892e-01],
#        [3.97139777e-01],
#        [1.11330638e+00],
#        [4.30496105e-02],
#        [1.72895886e+00],
#        [1.59527761e+00],
#        [9.71981334e-01],
#        [1.35560178e+00],
#        [1.83746687e+00],
#        [1.24383874e+00],
#        [3.47911333e-01],
#        [1.18696282e+00]])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_feat = PolynomialFeatures(degree=2,include_bias=False)

# %%
x_train_poly = poly_feat.fit_transform(x_train)

# %%
x_train_poly
# Out:
# array([[9.01747873e-01, 8.13149226e-01],
#        [3.63225703e-01, 1.31932911e-01],
#        [1.20943220e+00, 1.46272625e+00],
#        [1.36418697e-01, 1.86100608e-02],
#        [1.14497703e+00, 1.31097241e+00],
#        [6.30489606e-01, 3.97517144e-01],
#        [1.35813767e+00, 1.84453794e+00],
#        [1.17366668e+00, 1.37749348e+00],
#        [1.61898138e+00, 2.62110072e+00],
#        [9.80507045e-01, 9.61394066e-01],
#        [1.05542929e+00, 1.11393099e+00],
#        [1.94756708e+00, 3.79301752e+00],
#        [8.53402019e-01, 7.28295006e-01],
#        [1.01132433e+00, 1.02277690e+00],
#        [5.40416524e-01, 2.92050019e-01],
#        [1.78577742e+00, 3.18900098e+00],
#        [1.22406235e+00, 1.49832865e+00],
#        [1.54176782e+00, 2.37704801e+00],
#        [1.16402836e+00, 1.35496202e+00],
#        [1.96563423e+00, 3.86371792e+00],
#        [3.68020403e-01, 1.35439017e-01],
#        [1.65769162e+00, 2.74794149e+00],
#        [6.89473305e-01, 4.75373439e-01],
#        [7.80015428e-01, 6.08424068e-01],
#        [5.71152563e-01, 3.26215251e-01],
#        [1.83720356e+00, 3.37531691e+00],
#        [6.64127149e-01, 4.41064870e-01],
#        [1.60432217e+00, 2.57384962e+00],
#        [1.28313242e+00, 1.64642880e+00],
#        [1.94760416e+00, 3.79316195e+00],
#        [9.19760532e-01, 8.45959436e-01],
#        [1.34157758e+00, 1.79983041e+00],
#        [8.02959167e-01, 6.44743424e-01],
#        [1.15571443e+00, 1.33567585e+00],
#        [8.40387360e-01, 7.06250915e-01],
#        [1.46628505e+00, 2.14999185e+00],
#        [1.85236285e+00, 3.43124814e+00],
#        [1.50004353e+00, 2.25013058e+00],
#        [1.90035224e+00, 3.61133863e+00],
#        [1.03802325e+00, 1.07749228e+00],
#        [1.25615240e+00, 1.57791884e+00],
#        [2.61993690e-01, 6.86406934e-02],
#        [1.71662767e+00, 2.94681057e+00],
#        [1.39611450e+00, 1.94913569e+00],
#        [1.09909584e+00, 1.20801167e+00],
#        [7.55848359e-01, 5.71306741e-01],
#        [2.52659039e-01, 6.38365899e-02],
#        [7.64205504e-01, 5.84010052e-01],
#        [1.70979589e+00, 2.92340197e+00],
#        [2.70158316e-01, 7.29855158e-02],
#        [1.81078464e+00, 3.27894100e+00],
#        [1.68946889e+00, 2.85430513e+00],
#        [1.92652506e+00, 3.71149879e+00],
#        [1.65423094e+00, 2.73648001e+00],
#        [3.52392511e-01, 1.24180482e-01],
#        [8.04049783e-04, 6.46496053e-07],
#        [1.88021496e+00, 3.53520831e+00],
#        [1.20862097e+00, 1.46076464e+00],
#        [6.34767892e-01, 4.02930277e-01],
#        [3.97139777e-01, 1.57720002e-01],
#        [1.11330638e+00, 1.23945109e+00],
#        [4.30496105e-02, 1.85326897e-03],
#        [1.72895886e+00, 2.98929874e+00],
#        [1.59527761e+00, 2.54491065e+00],
#        [9.71981334e-01, 9.44747714e-01],
#        [1.35560178e+00, 1.83765619e+00],
#        [1.83746687e+00, 3.37628450e+00],
#        [1.24383874e+00, 1.54713480e+00],
#        [3.47911333e-01, 1.21042296e-01],
#        [1.18696282e+00, 1.40888073e+00]])

# %%
from sklearn.linear_model import LinearRegression

# %%
poly_reg = LinearRegression()

# %%
poly_reg
# Out:
# LinearRegression()

# %%
poly_reg.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
poly_reg.coef_
# Out:
# array([[2.95310012, 1.50774245]])

# %%
poly_reg.intercept_
# Out:
# array([4.53909595])

# %%
y_pred = poly_reg.predict(x_train_poly)

# %%
from sklearn.metrics import  r2_score,mean_squared_error

# %%
y_pred
# Out:
# array([[ 8.42806732],
#        [ 5.81065867],
#        [10.3160848 ],
#        [ 4.9700132 ],
#        [ 9.89693653],
#        [ 7.00034836],
#        [11.33090064],
#        [10.08195657],
#        [13.27205491],
#        [ 8.88416608],
#        [ 9.33540537],
#        [16.00935006],
#        [ 8.15735886],
#        [ 9.06772212],
#        [ 6.57533627],
#        [14.62086763],
#        [10.41296835],
#        [12.6760669 ],
#        [10.01952201],
#        [16.16930216],
#        [ 5.83010421],
#        [13.57761331],
#        [ 7.29192037],
#        [ 7.75990641],
#        [ 6.71761524],
#        [15.05365059],
#        [ 7.16534215],
#        [13.15752228],
#        [10.81070505],
#        [16.00967732],
#        [ 8.53072985],
#        [11.21458959],
#        [ 7.8824218 ],
#        [ 9.96589155],
#        [ 8.08568846],
#        [12.1108165 ],
#        [15.18274741],
#        [12.36149208],
#        [15.59599495],
#        [ 9.2290634 ],
#        [10.62773498],
#        [ 5.41628204],
#        [14.05150074],
#        [11.60075647],
#        [ 9.6062065 ],
#        [ 7.63257526],
#        [ 5.38147253],
#        [ 7.67640807],
#        [13.99603165],
#        [ 5.44694387],
#        [14.83032284],
#        [13.83182376],
#        [15.82430163],
#        [13.55011263],
#        [ 5.76697851],
#        [ 4.54147137],
#        [15.42174265],
#        [10.31073154],
#        [ 7.02114418],
#        [ 5.94969062],
#        [ 9.69557417],
#        [ 4.66902002],
#        [14.15197719],
#        [13.08718027],
#        [ 8.83389039],
#        [11.313036  ],
#        [15.05588707],
#        [10.5449571 ],
#        [ 5.74901356],
#        [10.16854528]])

# %%
r2_score(y_train,y_pred)
# Out:
# 0.9932122175186928

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 0.07769405125936943

# %%
plt.scatter(x_train,y_train,label = "train_data")
